# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("X_test.csv")
df
# Out:
#        vratios_Feature_1  vratios_Feature_2  vratios_Feature_3  \
# 0                   0.67               0.50               0.50
# 1                   1.00               1.00               1.00
# 2                   0.67               0.50               0.50
# 3                   0.33               0.33               0.17
# 4                   0.33               0.50               0.50
# ...                  ...                ...                ...
# 11427               0.33               0.33               0.50
# 11428               0.50               0.33               0.50
# 11429               0.17               0.17               0.33
# 11430               0.67               0.67               0.83
# 11431               0.17               0.33               0.33
#
#        vratios_Feature_4  vratios_Feature_5  vratios_Feature_6  \
# 0                   0.33               0.50               0.33
# 1                   1.00               0.50               0.83
# ...

# %%
df.describe()
# Out:
#        vratios_Feature_1  vratios_Feature_2  vratios_Feature_3  \
# count       11432.000000       11432.000000       11432.000000
# mean            0.500000           0.500000           0.500000
# std             0.232257           0.232257           0.232257
# min             0.000000           0.000000           0.000000
# 25%             0.330000           0.330000           0.330000
# 50%             0.500000           0.500000           0.500000
# 75%             0.670000           0.670000           0.670000
# max             1.000000           1.000000           1.000000
#
#        vratios_Feature_4  vratios_Feature_5  vratios_Feature_6  \
# count       11432.000000       11432.000000       11432.000000
# mean            0.500000           0.500000           0.500000
# std             0.232257           0.232257           0.232257
# min             0.000000           0.000000           0.000000
# 25%             0.330000           0.330000           0.330000
# ...

# %%
df.describe()
# Out:
#        vratios_Feature_1  vratios_Feature_2  vratios_Feature_3  \
# count       11432.000000       11432.000000       11432.000000
# mean            0.500000           0.500000           0.500000
# std             0.232257           0.232257           0.232257
# min             0.000000           0.000000           0.000000
# 25%             0.330000           0.330000           0.330000
# 50%             0.500000           0.500000           0.500000
# 75%             0.670000           0.670000           0.670000
# max             1.000000           1.000000           1.000000
#
#        vratios_Feature_4  vratios_Feature_5  vratios_Feature_6  \
# count       11432.000000       11432.000000       11432.000000
# mean            0.500000           0.500000           0.500000
# std             0.232257           0.232257           0.232257
# min             0.000000           0.000000           0.000000
# 25%             0.330000           0.330000           0.330000
# ...
